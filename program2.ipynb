# %%
#Generate a Data set for Health Care using the following:
#people = ['kiran', arun', 'vijay', 'varun']
#age =[25, 30, 35, 40, 45]
#height =[145, 151, 165, 173]
#weight=[45, 55, 65, 75]

import matplotlib.pyplot as plt

people = ['Kiran', 'Arun', 'Vijay', 'Varun']
age = [25, 30, 35, 40]
height = [145, 151, 165, 173]
weight = [45, 55, 65, 75]

# Bar graph for age
plt.bar(people, age, color='blue', label='Age')
plt.xlabel('People')
plt.ylabel('Age')
plt.title('Age Distribution')
plt.legend()
plt.show()

# Bar graph for height
plt.bar(people, height, color='green', label='Height')
plt.xlabel('People')
plt.ylabel('Height')
plt.title('Height Distribution')
plt.legend()
plt.show()

# Bar graph for weight
plt.bar(people, weight, color='orange', label='Weight')
plt.xlabel('People')
plt.ylabel('Weight')
plt.title('Weight Distribution')
plt.legend()
plt.show()
#---------------------------------------------------------------------------------------------------------------------
#SCATTER PLOT


people = ['kiran', 'arun', 'vijay', 'varun']
age = [25, 30, 35, 40]
height = [145, 151, 165, 173]
weight = [45, 55, 65, 75]

# Scatter plot
plt.scatter(age, height, label='Height', color='blue')
plt.scatter(age, weight, label='Weight', color='red')

# Adding labels and title
plt.xlabel('Age')
plt.ylabel('Value')
plt.title('Scatter Plot of Age, Height, and Weight')
plt.legend()

# Display the plot
plt.show()
#------------------------------
import matplotlib.pyplot as plt

people = ['kiran', 'arun', 'vijay', 'varun']
age = [25, 30, 35, 40, 45]
height = [145, 151, 165, 173]
weight = [45, 55, 65, 75]

# Plotting histograms
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.hist(age, bins=5, color='blue', edgecolor='black')
plt.title('Age Histogram')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.subplot(2, 2, 2)
plt.hist(height, bins=5, color='green', edgecolor='black')
plt.title('Height Histogram')
plt.xlabel('Height')
plt.ylabel('Frequency')

plt.subplot(2, 2, 3)
plt.hist(weight, bins=5, color='orange', edgecolor='black')
plt.title('Weight Histogram')
plt.xlabel('Weight')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
